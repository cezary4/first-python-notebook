# %%
2+2
# Out:
# 4

# %%
import pandas

# %%
# %matplotlib inline

# %%
pandas.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
2+2
# Out:
# 4

# %%
props = pandas.read_csv('prop-committees.csv')

# %%
props
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 5    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 6    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 7    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 8    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 9    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 10   ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 11   ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# ...

# %%
print props
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 5    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 6    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 7    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 8    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 9    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 10   ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 11   ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# ...

# %%
props.head
# Out:
# <bound method DataFrame.head of                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 5    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 6    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 7    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 8    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 9    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 10   ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# ...

# %%
props.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4  ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4            71  PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# ...

# %%
props.head(2)
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# 1                383                 1220380
#
#                                       committee_name committee_position
# 0  YES ON PROPOSITION 51 - CALIFORNIANS FOR QUALI...            SUPPORT
# 1  COMMUNITY COLLEGE FACILITY COALITION ISSUES CO...            SUPPORT

# %%
props.tail(2)
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 100  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
# 101  ocd-contest/7495cdbe-1aa7-4c26-9a55-aa4130347b95            1372638
#
#      ccdc_prop_id                                          prop_name  \
# 100            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
# 101            86  PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...
#
#      ccdc_committee_id  calaccess_committee_id  \
# 100                482                 1381938
# 101                483                 1389817
#
#                                         committee_name committee_position
# 100      SAVE THE BAY ACTION FUND PAC - YES ON PROP 67            SUPPORT
# 101  SAVE THE BAY ACTION FUND COMMITTEE TO SUPPORT ...            SUPPORT

# %%
props.info
# Out:
# <bound method DataFrame.info of                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 5    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 6    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 7    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 8    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 9    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 10   ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# ...

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %%
props.prop_name
# Out:
# 0      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 5      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 6      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 7      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 8      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 9      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 10     PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 11     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 12     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 13     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 14     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 15     PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...
# ...

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %%
props.prop_name.value_counts().reset_index()
# Out:
#                                                 index  prop_name
# 0   PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...         13
# 1   PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...         12
# 2   PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...         11
# 3   PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...          9
# 4   PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...          8
# 5   PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...          7
# 6   PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...          7
# 7   PROPOSITION 059- SB 254 (CHAPTER 20, STATUTES ...          6
# 8   PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...          4
# 9   PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...          4
# 10  PROPOSITION 058 - SB 1174 (CHAPTER 753, STATUT...          4
# 11  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...          4
# 12  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...          4
# ...

# %%
props.committee_position.value_counts().reset_index()
# Out:
#      index  committee_position
# 0  SUPPORT                  72
# 1   OPPOSE                  30

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %%
props[props.prop_name == 'PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.']
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 74  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 75  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 76  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 77  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 78  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 79  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 80  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 81  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 82  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 83  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 84  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#     ccdc_prop_id                                          prop_name  \
# ...

# %%
pot = props[props.prop_name == 'PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.']

# %%
pot.head
# Out:
# <bound method DataFrame.head of                                          ocd_prop_id  calaccess_prop_id  \
# 74  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 75  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 76  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 77  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 78  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 79  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 80  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 81  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 82  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 83  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 84  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#     ccdc_prop_id                                          prop_name  \
# ...

# %%
pot.head()
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 74  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 75  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 76  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 77  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 78  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#     ccdc_prop_id                                          prop_name  \
# 74            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 75            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 76            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 77            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 78            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 74                456                 1381808
# ...

# %%
pot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 74 to 84
# Data columns (total 8 columns):
# ocd_prop_id               11 non-null object
# calaccess_prop_id         11 non-null int64
# ccdc_prop_id              11 non-null int64
# prop_name                 11 non-null object
# ccdc_committee_id         11 non-null int64
# calaccess_committee_id    11 non-null int64
# committee_name            11 non-null object
# committee_position        11 non-null object
# dtypes: int64(4), object(4)
# memory usage: 792.0+ bytes

# %%
pandas.read_csv('contributions.csv')
# Out:
#        calaccess_committee_id  \
# 0                     1386560
# 1                     1386560
# 2                     1386560
# 3                     1386560
# 4                     1386560
# 5                     1386560
# 6                     1386560
# 7                     1386560
# 8                     1386560
# 9                     1386560
# 10                    1386560
# 11                    1386560
# 12                    1386560
# 13                    1386560
# 14                    1386560
# 15                    1386560
# 16                    1386560
# 17                    1386560
# 18                    1386560
# 19                    1386560
# 20                    1386560
# 21                    1386560
# 22                    1386560
# 23                    1386560
# 24                    1386560
# 25                    1386560
# 26                    1372902
# 27                    1372902
# 28                    1372902
# 29                    1372902
# ...

# %%
contribs = pandas.read_csv('contributions.csv')

# %%
contribs.head(10)
# Out:
#    calaccess_committee_id                              committee_name  \
# 0                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 1                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 2                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 4                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 5                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 6                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 7                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 8                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 9                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
#
#    calaccess_filing_id date_received contributor_lastname  \
# 0              2083796    2016-09-18              BERGMAN
# 1              2083796    2016-09-18                KAHLE
# ...

# %%
contribs.tail(10)
# Out:
#        calaccess_committee_id  \
# 56751                 1362973
# 56752                 1362973
# 56753                 1362973
# 56754                 1362973
# 56755                 1362973
# 56756                 1362973
# 56757                 1362973
# 56758                 1362973
# 56759                 1362973
# 56760                 1362973
#
#                                           committee_name  calaccess_filing_id  \
# 56751  YES ON PROPOSITION 52 - A COALITION OF CALIFOR...              1962988
# 56752  YES ON PROPOSITION 52 - A COALITION OF CALIFOR...              1962988
# 56753  YES ON PROPOSITION 52 - A COALITION OF CALIFOR...              1962988
# 56754  YES ON PROPOSITION 52 - A COALITION OF CALIFOR...              1962988
# 56755  YES ON PROPOSITION 52 - A COALITION OF CALIFOR...              1980342
# 56756  YES ON PROPOSITION 52 - A COALITION OF CALIFOR...              2009922
# 56757  YES ON PROPOSITION 52 - A COALITION OF CALIFOR...              2009922
# ...

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56761 entries, 0 to 56760
# Data columns (total 13 columns):
# calaccess_committee_id          56761 non-null int64
# committee_name                  56761 non-null object
# calaccess_filing_id             56761 non-null int64
# date_received                   56761 non-null object
# contributor_lastname            56757 non-null object
# contributor_firstname           53794 non-null object
# contributor_city                56751 non-null object
# contributor_state               56745 non-null object
# contributor_zip                 56748 non-null object
# contributor_employer            48962 non-null object
# contributor_occupation          53656 non-null object
# contributor_is_self_employed    56761 non-null bool
# amount                          56761 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 5.3+ MB

# %%
pot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 74 to 84
# Data columns (total 8 columns):
# ocd_prop_id               11 non-null object
# calaccess_prop_id         11 non-null int64
# ccdc_prop_id              11 non-null int64
# prop_name                 11 non-null object
# ccdc_committee_id         11 non-null int64
# calaccess_committee_id    11 non-null int64
# committee_name            11 non-null object
# committee_position        11 non-null object
# dtypes: int64(4), object(4)
# memory usage: 792.0+ bytes

# %%
pandas.merge(pot, contribs, on='calaccess_committee_id')
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 1    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 2    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 3    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 4    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 5    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 6    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 7    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 8    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 9    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 10   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 11   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# ...

# %%
merged = pandas.merge(pot, contribs, on='calaccess_committee_id')

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 860 entries, 0 to 859
# Data columns (total 20 columns):
# ocd_prop_id                     860 non-null object
# calaccess_prop_id               860 non-null int64
# ccdc_prop_id                    860 non-null int64
# prop_name                       860 non-null object
# ccdc_committee_id               860 non-null int64
# calaccess_committee_id          860 non-null int64
# committee_name_x                860 non-null object
# committee_position              860 non-null object
# committee_name_y                860 non-null object
# calaccess_filing_id             860 non-null int64
# date_received                   860 non-null object
# contributor_lastname            860 non-null object
# contributor_firstname           750 non-null object
# contributor_city                860 non-null object
# contributor_state               860 non-null object
# contributor_zip                 860 non-null object
# ...

# %%
pandas.merge(pot, contribs, left_on='calaccess_committee_id', right_on='calaccess_committee_id')
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 1    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 2    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 3    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 4    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 5    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 6    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 7    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 8    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 9    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 10   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 11   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# ...

# %%
merged.sort_values('amount')
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 260  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 793  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 806  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 727  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 698  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 227  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 812  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 126  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 117  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 220  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 100  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 28   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# ...

# %%
merged.sort_values('amount', ascending=False)
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 141  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 78   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 846  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 851  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 852  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 140  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 259  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 77   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 254  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 253  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 850  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 839  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# ...

# %%
merged.sort_values('amount', ascending=False)
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 141  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 78   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 846  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 851  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 852  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 140  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 259  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 77   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 254  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 253  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 850  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 839  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# ...

# %%
merged.amount.sum()
# Out:
# 35177017.640000001

# %%
merged.sort_values(['contributor_lastname','amount'], ascending=[False, False])
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 476  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 731  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 475  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 175  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 473  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 474  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 388  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 730  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 472  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 174  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 729  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 788  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# ...

# %%
merged[merged.committee_position == 'SUPPORT']
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 1    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 2    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 3    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 4    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 5    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 6    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 7    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 8    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 9    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 10   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 11   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# ...

# %%
support = merged[merged.committee_position == 'SUPPORT']

# %%
oppose = merged[merged.committee_position == 'OPPOSE']

# %%
support.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 1  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 2  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 3  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 4  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#    ccdc_prop_id                                          prop_name  \
# 0            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 1            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 2            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 3            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 4            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                456                 1381808
# ...

# %%
oppose.head()
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 261  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 262  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 263  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 264  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 265  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#      ccdc_prop_id                                          prop_name  \
# 261            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 262            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 263            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 264            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 265            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#      ccdc_committee_id  calaccess_committee_id  \
# 261                459                 1382568
# ...

# %%
len(support)
# Out:
# 762

# %%
len(oppose)
# Out:
# 98

# %%
oppose.sort_values('amount',ascending=False).head(10)
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 839  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 312  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 310  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 308  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 840  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 837  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 838  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 287  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 836  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 306  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#      ccdc_prop_id                                          prop_name  \
# 839            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# ...

# %%
support.amount.sum()
# Out:
# 32675806.0

# %%
merged.amount.sum()
# Out:
# 35177017.640000001

# %%
support.amount.sum()/merged.amount.sum()
# Out:
# 0.92889642704798669

# %%
oppose.amount.sum()
# Out:
# 2501211.6400000001

# %%
oppose.amount.sum()/merged.amount.sum()
# Out:
# 0.071103572952013333

# %%
support.amount.mean()
# Out:
# 42881.635170603673

# %%
oppose.amount.mean()
# Out:
# 25522.567755102042

# %%
support.amount.describe()
# Out:
# count       762.000
# mean      42881.635
# std      234132.753
# min     -150000.000
# 25%         100.000
# 50%         100.000
# 75%         250.000
# max     4000000.000
# Name: amount, dtype: float64

# %%
support.groupby(['contributor_lastname','contributor_firstname']).amount.sum()
# Out:
# contributor_lastname  contributor_firstname
# ABEL                  MATTHEW                   200.000
# AGUIRRE               KRISTINA                  100.000
# AHMED                 ABDUL                     200.000
# AINSWORTH             MARK                      600.000
# ALBRAND               ANTON                    1100.000
# ANDERSON              DANA                      100.000
# ANDRESEN              MATHEW                    100.000
# ANGEL                 GARYN                     100.000
# ANGUHALDO             CESAR                     100.000
# ANTHONY               JAMES                     250.000
# ARBOUR                JOHN                      100.000
# ARCE                  JOSHUA                    100.000
# ARIAS                 CARLOS                    250.000
# ARKENBERG             CHRISTOPHER               100.000
# AROTH                 SYLVIA                   1000.000
# AUSTIN                JAMES F.                 1000.000
# ...

# %%
support.groupby(['contributor_lastname','contributor_firstname']).amount.sum().reset_index().sort_values('amount', ascending=False)
# Out:
#                contributor_lastname contributor_firstname      amount
# 337  PARKER AND AFFILIATED ENTITIES                  SEAN 7250000.000
# 336                          PARKER                  SEAN 1500000.000
# 265                           LEWIS                DANIEL 1250000.000
# 457                   VAN AMERINGEN                 HENRY 1000000.000
# 364                        PRITZKER              NICHOLAS  900000.000
# 445                           THIEL                 PETER  300000.000
# 221                         JENKINS                 ROGER   75000.000
# 208                          HOWARD                ANGELA   65000.000
# 194                            HESS              LAWRENCE   30000.000
# 489                        WILLIAMS           ZACHARY PYM   10000.000
# 359                            POST                 JASON   10000.000
# 297                         MCNAMEE              ROGER B.   10000.000
# ...

# %%
oppose.groupby(['contributor_lastname','contributor_firstname']).amount.sum().reset_index().sort_values('amount', ascending=False)
# Out:
#              contributor_lastname contributor_firstname      amount
# 35                        SCHAUER                 JULIE 1364000.000
# 0                           ADAMS                ROBERT    6500.000
# 12                           DEAN               MICHAEL    5000.000
# 3                            BELL                GEORGE    1550.000
# 15                         FARDAD               FARSHAD    1000.000
# 30                        REUVENI                 EDITH    1000.000
# 24                         MACIEL               JESSICA    1000.000
# 28                         MILLER             CHRISTINE     871.000
# 32                       ROBINSON                  LORI     817.000
# 2                            BELL                DWIGHT     730.000
# 11                         DAWSON                THOMAS     500.000
# 39                     TABIBZADEH               KOLALEH     500.000
# 25                        MADDAHI               KOUROSH     500.000
# ...

# %%
merged.groupby(['contributor_lastname','contributor_firstname','committee_position']).amount.sum().reset_index().sort_values('amount', ascending=False)
# Out:
#                contributor_lastname contributor_firstname committee_position  \
# 367  PARKER AND AFFILIATED ENTITIES                  SEAN            SUPPORT
# 366                          PARKER                  SEAN            SUPPORT
# 437                         SCHAUER                 JULIE             OPPOSE
# 289                           LEWIS                DANIEL            SUPPORT
# 498                   VAN AMERINGEN                 HENRY            SUPPORT
# 394                        PRITZKER              NICHOLAS            SUPPORT
# 486                           THIEL                 PETER            SUPPORT
# 242                         JENKINS                 ROGER            SUPPORT
# 228                          HOWARD                ANGELA            SUPPORT
# 214                            HESS              LAWRENCE            SUPPORT
# 389                            POST                 JASON            SUPPORT
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 860 entries, 0 to 859
# Data columns (total 20 columns):
# ocd_prop_id                     860 non-null object
# calaccess_prop_id               860 non-null int64
# ccdc_prop_id                    860 non-null int64
# prop_name                       860 non-null object
# ccdc_committee_id               860 non-null int64
# calaccess_committee_id          860 non-null int64
# committee_name_x                860 non-null object
# committee_position              860 non-null object
# committee_name_y                860 non-null object
# calaccess_filing_id             860 non-null int64
# date_received                   860 non-null object
# contributor_lastname            860 non-null object
# contributor_firstname           750 non-null object
# contributor_city                860 non-null object
# contributor_state               860 non-null object
# contributor_zip                 860 non-null object
# ...

# %%
merged.groupby(['contributor_employer','committee_position']).amount.sum().reset_index().sort_values('amount', ascending=False).head(10)
# Out:
#           contributor_employer committee_position      amount
# 349     SEAN PARKER FOUNDATION            SUPPORT 1250000.000
# 320                    RETIRED            SUPPORT  502300.000
# 381   TAO CAPITAL PARTNERS LLC            SUPPORT  450000.000
# 382  TAO CAPITAL PARTNERS, LLC            SUPPORT  450000.000
# 392         THIEL CAPITAL, LLC            SUPPORT  300000.000
# 348   SEAN N PARKER FOUNDATION            SUPPORT  250000.000
# 292                       NONE            SUPPORT   86927.000
# 134                   DESIGNER            SUPPORT   65000.000
# 237       LEHBROS LIMITED, LLC            SUPPORT   30000.000
# 310      POST INVESTMENT GROUP            SUPPORT   10000.000

# %%
support.groupby(['contributor_employer']).amount.sum().reset_index().sort_values('amount', ascending=False).head(20)
# Out:
#           contributor_employer      amount
# 322     SEAN PARKER FOUNDATION 1250000.000
# 294                    RETIRED  502300.000
# 351  TAO CAPITAL PARTNERS, LLC  450000.000
# 350   TAO CAPITAL PARTNERS LLC  450000.000
# 361         THIEL CAPITAL, LLC  300000.000
# 321   SEAN N PARKER FOUNDATION  250000.000
# 268                       NONE   86927.000
# 115                   DESIGNER   65000.000
# 216       LEHBROS LIMITED, LLC   30000.000
# 95         CONDE NAST TRAVELER   10000.000
# 286      POST INVESTMENT GROUP   10000.000
# 133         ELEVATION PARTNERS   10000.000
# 212            LAURIE BENENSON    5000.000
# 71               CAMILLA FIELD    5000.000
# 33                 AROMAFLORIA    5000.000
# 13          AKONADI FOUNDATION    5000.000
# 102           CULTURE MAGAZINE    5000.000
# 144                  FLOW KANA    3850.000
# 203              KHURSID KHOJA    3300.000
# 381                    W VAPES    3000.000

# %%
merged.groupby(['contributor_employer']).amount.sum().reset_index().sort_values('contributor_employer')
# Out:
#                         contributor_employer     amount
# 0                    360SWEATER COMPANY, LLC    360.000
# 1     3C - COMPREHENSIVE CANNABIS CONSULTING    100.000
# 2                            4FRONT VENTURES    100.000
# 3                               5AM VENTURES    500.000
# 4                                 745 AGENCY    250.000
# 5                             7TH POINT, LLC    100.000
# 6                                 A NEW PATH     84.000
# 7      ACLU OF SAN DIEGO & IMPERIAL COUNTIES    250.000
# 8                        AD PRODUCTIONS, LLC    100.000
# 9                                 ADAM ELLIS    100.000
# 10                              ADR SERVICES    300.000
# 11                             AEROWIND CORP    100.000
# 12                                    AGZAAR    200.000
# 13                         AJA VIDEO SYSTEMS    100.000
# 14                        AKONADI FOUNDATION   5000.000
# 15                            ALAMEDA COUNTY    200.000
# ...

# %%
def clean_row(row):
    if row.contributor_employer.str.startswith('TAO CAPITAL PARTNERS'):
        return "TAO CAPITAL PARTNERS"
    else:
        row.contributor_employer

# %%
top_supporters = support.groupby(['contributor_lastname','contributor_firstname']).amount.sum().reset_index().sort_values('amount', ascending=False).head(10)

# %%
top_supporters.amount.plot.barh()

# %%
chart = top_supporters.amount.plot.barh()
chart.set_yticklabels(top_supporters.contributor_lastname)

# %%
top_supporters["contributor_fullname"] = top_supporters.contributor_firstname + " " + top_supporters.contributor_lastname

# %%
top_supporters
# Out:
#                contributor_lastname contributor_firstname      amount  \
# 337  PARKER AND AFFILIATED ENTITIES                  SEAN 7250000.000
# 336                          PARKER                  SEAN 1500000.000
# 265                           LEWIS                DANIEL 1250000.000
# 457                   VAN AMERINGEN                 HENRY 1000000.000
# 364                        PRITZKER              NICHOLAS  900000.000
# 445                           THIEL                 PETER  300000.000
# 221                         JENKINS                 ROGER   75000.000
# 208                          HOWARD                ANGELA   65000.000
# 194                            HESS              LAWRENCE   30000.000
# 489                        WILLIAMS           ZACHARY PYM   10000.000
#
#                     contributor_fullname
# 337  SEAN PARKER AND AFFILIATED ENTITIES
# 336                          SEAN PARKER
# 265                         DANIEL LEWIS
# ...

# %%
chart = top_supporters.amount.plot.barh()
chart.set_yticklabels(top_supporters.contributor_fullname)

# %%
top_supporters.to_csv("top-supporters.csv", index=False)

# %%
top_opponents = oppose.groupby(['contributor_lastname','contributor_firstname']).amount.sum().reset_index().sort_values('amount', ascending=False).head(10)

# %%
chart = top_opponents.amount.plot.barh()
chart.set_yticklabels(top_opponents.contributor_lastname)

# %%
top_opponents["contributor_fullname"] = top_opponents.contributor_firstname + " " + top_opponents.contributor_lastname

# %%
top_opponents
# Out:
#    contributor_lastname contributor_firstname      amount contributor_fullname
# 35              SCHAUER                 JULIE 1364000.000        JULIE SCHAUER
# 0                 ADAMS                ROBERT    6500.000         ROBERT ADAMS
# 12                 DEAN               MICHAEL    5000.000         MICHAEL DEAN
# 3                  BELL                GEORGE    1550.000          GEORGE BELL
# 15               FARDAD               FARSHAD    1000.000       FARSHAD FARDAD
# 30              REUVENI                 EDITH    1000.000        EDITH REUVENI
# 24               MACIEL               JESSICA    1000.000       JESSICA MACIEL
# 28               MILLER             CHRISTINE     871.000     CHRISTINE MILLER
# 32             ROBINSON                  LORI     817.000        LORI ROBINSON
# 2                  BELL                DWIGHT     730.000          DWIGHT BELL

# %%
chart = top_opponents.amount.plot.barh()
chart.set_yticklabels(top_opponents.contributor_fullname)

# %%
top_opponents.to_csv("top-opponents.csv", index=False)
